# %%
import pandas as pd

# %%
df = pd.read_csv("experiments21-05-2018.csv")

# %%
df
# Out:
#           Dataset  Number Functions  Number Relations  \
# 0        FUNLIBTH                19                32
# 1          FUNABE                 9                 8
# 2          FUNMB1                23                42
# 3          FUNLF1                17                30
# 4          ISBNdb                14                20
# 5             IVA                12                18
# 6              IE                19                42
# 7   FUNLIBTH + IE                38                52
# 8     FUNABE + IE                28                44
# 9     FUNMB1 + IE                42                62
# 10    FUNLF1 + IE                36                50
# 11    ISBNdb + IE                33                56
# 12       IVA + IE                31                52
# 13            ALL                74                82
#
#     Naturally reachable with subfunctions  \
# 0                               43.750000
# 1                               62.500000
# ...

# %%
df.columns
# Out:
# Index(['Dataset', 'Number Functions', 'Number Relations',
#        'Naturally reachable with subfunctions',
#        'Naturally reachable without subfunctions', 'DFS Weak', 'DFS Weak time',
#        'DFS Strong', 'DFS Strong time', 'Smootie', 'Smootie time'],
#       dtype='object')

# %%
df[["Dataset", 'DFS Weak', 'DFS Strong', 'Smootie']]
# Out:
#           Dataset   DFS Weak  DFS Strong    Smootie
# 0        FUNLIBTH  43.750000   43.750000  43.750000
# 1          FUNABE  75.000000   75.000000  75.000000
# 2          FUNMB1  50.000000   47.619048  47.619048
# 3          FUNLF1  53.333333   50.000000  50.000000
# 4          ISBNdb  65.000000   65.000000  65.000000
# 5             IVA  55.555556   55.555556  55.555556
# 6              IE   0.000000    0.000000   0.000000
# 7   FUNLIBTH + IE  71.153846   34.615385  28.846154
# 8     FUNABE + IE  25.000000   13.636364  13.636364
# 9     FUNMB1 + IE  67.741935   35.483871  33.870968
# 10    FUNLF1 + IE  72.000000   32.000000  32.000000
# 11    ISBNdb + IE  32.142857   23.214286  23.214286
# 12       IVA + IE  48.076923   21.153846  21.153846
# 13            ALL  76.829268   53.658537  52.439024
